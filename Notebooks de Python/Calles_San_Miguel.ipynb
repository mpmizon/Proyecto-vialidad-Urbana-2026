# %%
# ==========================================
# Jupyter Notebook: Extracción de Malla Vial
# Comuna: San Miguel, Santiago, Chile
# Autor: Gerardo Ureta, PhD(c) en Industria Inteligente, PUCV
# ==========================================

# 1. Instalación de librerías (ejecutar una vez)
# !pip install osmnx geopandas shapely fiona pyproj
# Out:
# Requirement already satisfied: osmnx in /usr/local/lib/python3.12/dist-packages (2.1.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (2.1.2)
# Requirement already satisfied: fiona in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (3.7.2)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.30 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas) (26.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from fiona) (26.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from fiona) (2026.4.22)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.12/dist-packages (from fiona) (8.3.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.12/dist-packages (from fiona) (1.1.1.2)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from fiona) (0.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->osmnx) (1.17.0)

# %%
# 2. Importación de librerías
import osmnx as ox
import geopandas as gpd

# Configuración opcional
ox.settings.log_console = True
ox.settings.use_cache = True

# %%
# 3. Definir área de estudio
place_name = "San Miguel, Santiago, Chile"

# %%
# 4. Descargar red vial desde OpenStreetMap
# network_type="drive" -> solo calles transitables por vehículos
G = ox.graph_from_place(place_name, network_type='drive')

# %%
# 5. Convertir grafo a GeoDataFrames
nodes, edges = ox.graph_to_gdfs(G)

# %%
# 6. Revisar estructura
print(edges.head())
print(edges.crs)
# Out:
#                               osmid   highway lanes maxspeed  \
# u         v          key
# 14760603  243485726  0    355376018   primary     2       50
#           335617919  0    649329116  tertiary     3       50
# 14760609  3010902319 0     22698947   primary     2      NaN
#           267807538  0     38942685  tertiary     2      NaN
# 149825401 5148748242 0    860489355   primary     3       50
#
#                                                     name  oneway  reversed  \
# u         v          key
# 14760603  243485726  0                          Euclides    True     False
#           335617919  0             San Ignacio de Loyola    True     False
# 14760609  3010902319 0                              Orán    True     False
#           267807538  0                          Euclides    True     False
# 149825401 5148748242 0    Avenida Carlos Silva Vildósola    True     False
#
#                               length  \
# u         v          key
# 14760603  243485726  0     66.169372
#           335617919  0     58.387989
# 14760609  3010902319 0    150.503584
#           267807538  0    107.073307
# 149825401 5148748242 0     12.792178
#
#                                                                    geometry  \
# u         v          key
# 14760603  243485726  0    LINESTRING (-70.65394 -33.4773, -70.65385 -33....
#           335617919  0    LINESTRING (-70.65394 -33.4773, -70.65393 -33....
# 14760609  3010902319 0    LINESTRING (-70.65051 -33.47843, -70.6504 -33....
#           267807538  0    LINESTRING (-70.65051 -33.47843, -70.65037 -33...
# 149825401 5148748242 0    LINESTRING (-70.64816 -33.47764, -70.64823 -33...
#
#                          junction access width bridge  ref
# u         v          key
# 14760603  243485726  0        NaN    NaN   NaN    NaN  NaN
#           335617919  0        NaN    NaN   NaN    NaN  NaN
# 14760609  3010902319 0        NaN    NaN   NaN    NaN  NaN
#           267807538  0        NaN    NaN   NaN    NaN  NaN
# 149825401 5148748242 0        NaN    NaN   NaN    NaN  NaN
# epsg:4326

# %%
# 7. Reproyectar a sistema de coordenadas adecuado para Chile
# WGS84 -> EPSG:4326 (por defecto)
# Proyección recomendada: EPSG:32719 (UTM Zona 19 Sur)
edges_proj = edges.to_crs(epsg=32719)

# %%
# 8. Guardar como Shapefile
output_path = "malla_vial_san_miguel.shp"
edges_proj.to_file(output_path)

print(f"Archivo guardado en: {output_path}")
# Out:
# Archivo guardado en: malla_vial_san_miguel.shp

# %%
# 9. (Opcional) Visualización rápida
edges_proj.plot(figsize=(10,10))
# Out:
# <Axes: >

# %%
# ==========================================
# Notas técnicas:
# - Fuente de datos: OpenStreetMap
# - Precisión depende del mapeo colaborativo
# - Puede filtrarse por tipo de vía (highway)
# ==========================================

# %%
# 10. Filtrar tipos de calles
# Ejemplo: excluir caminos menores
if 'highway' in edges.columns:
    edges_filtrado = edges[edges['highway'].isin(['primary','secondary','tertiary','residential'])]
    edges_filtrado = edges_filtrado.to_crs(epsg=32719)
    edges_filtrado.to_file("malla_vial_filtrada.shp")
    print("Archivo filtrado guardado")
# Out:
# Archivo filtrado guardado

# %%
# 11. Exportar nodos también
nodes_proj = nodes.to_crs(epsg=32719)
nodes_proj.to_file("nodos_viales_san_miguel.shp")

print("Proceso completado correctamente")
# Out:
# Proceso completado correctamente
# /tmp/ipykernel_4236/1804516133.py:3: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   nodes_proj.to_file("nodos_viales_san_miguel.shp")
# /usr/local/lib/python3.12/dist-packages/pyogrio/raw.py:733: RuntimeWarning: Normalized/laundered field name: 'street_count' to 'street_cou'
#   ogr_write(

# %% [markdown]
# Intersecciones críticas (nodos)

# %%
import osmnx as ox
G = ox.graph_from_place("San Miguel, Santiago, Chile", network_type="drive")
nodes, edges = ox.graph_to_gdfs(G)

# Nodos con alta conectividad
nodos_criticos = nodes[nodes['street_count'] >= 4]
